# %% [markdown]
# # Linear Regression

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Mall_Customers.csv')
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x = data[['Annual Income (k$)']].values
y = data['Spending Score (1-100)'].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as pyplot
pyplot.xlabel("Annual Income")
pyplot.ylabel("Spending Score")
pyplot.scatter(x,y)
pyplot.plot(x,lin_reg.predict(x),color='black')
pyplot.title('Linear Regression Line')
pyplot.show()

# %%
m = lin_reg.coef_

# %%
c = lin_reg.intercept_

# %%
y = m*x+c
y
# Out:
# array([[49.75640514],
#        [49.75640514],
#        [49.76614164],
#        [49.76614164],
#        [49.77587814],
#        [49.77587814],
#        [49.78561463],
#        [49.78561463],
#        [49.79535113],
#        [49.79535113],
#        [49.79535113],
#        [49.79535113],
#        [49.80508763],
#        [49.80508763],
#        [49.80508763],
#        [49.80508763],
#        [49.81482413],
#        [49.81482413],
#        [49.83429712],
#        [49.83429712],
#        [49.84403362],
#        [49.84403362],
#        [49.85377012],
#        [49.85377012],
#        [49.88297962],
#        [49.88297962],
#        [49.88297962],
#        [49.88297962],
#        [49.89271611],
#        [49.89271611],
#        [49.90245261],
#        [49.90245261],
#        [49.93166211],
#        [49.93166211],
#        [49.93166211],
#        [49.93166211],
#        [49.94139861],
#        [49.94139861],
#        [49.9706081 ],
#        [49.9706081 ],
#        [49.9803446 ],
#        [49.9803446 ],
#        [49.9900811 ],
#        [49.9900811 ],
#        [49.9900811 ],
#        [49.9900811 ],
#        [49.9998176 ],
#        [49.9998176 ],
#        [49.9998176 ],
#        [49.9998176 ],
#        [50.01929059],
#        [50.01929059],
#        [50.02902709],
#        [50.02902709],
#        [50.02902709],
#        [50.02902709],
#        [50.03876359],
#        [50.03876359],
#        [50.05823659],
#        [50.05823659],
#        [50.05823659],
#        [50.05823659],
#        [50.06797308],
#        [50.06797308],
#        [50.07770958],
#        [50.07770958],
#        [50.07770958],
#        [50.07770958],
#        [50.07770958],
#        [50.07770958],
#        [50.08744608],
#        [50.08744608],
#        [50.09718258],
#        [50.09718258],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.13612857],
#        [50.16533807],
#        [50.16533807],
#        [50.17507456],
#        [50.17507456],
#        [50.18481106],
#        [50.18481106],
#        [50.19454756],
#        [50.19454756],
#        [50.19454756],
#        [50.19454756],
#        [50.19454756],
#        [50.19454756],
#        [50.20428406],
#        [50.20428406],
#        [50.21402056],
#        [50.21402056],
#        [50.21402056],
#        [50.21402056],
#        [50.21402056],
#        [50.21402056],
#        [50.22375706],
#        [50.22375706],
#        [50.22375706],
#        [50.22375706],
#        [50.22375706],
#        [50.22375706],
#        [50.23349355],
#        [50.23349355],
#        [50.24323005],
#        [50.24323005],
#        [50.24323005],
#        [50.24323005],
#        [50.26270305],
#        [50.26270305],
#        [50.26270305],
#        [50.26270305],
#        [50.28217605],
#        [50.28217605],
#        [50.29191254],
#        [50.29191254],
#        [50.30164904],
#        [50.30164904],
#        [50.30164904],
#        [50.30164904],
#        [50.30164904],
#        [50.30164904],
#        [50.31138554],
#        [50.31138554],
#        [50.32112204],
#        [50.32112204],
#        [50.32112204],
#        [50.32112204],
#        [50.33085854],
#        [50.33085854],
#        [50.34059504],
#        [50.34059504],
#        [50.35033153],
#        [50.35033153],
#        [50.36006803],
#        [50.36006803],
#        [50.36006803],
#        [50.36006803],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.36980453],
#        [50.37954103],
#        [50.37954103],
#        [50.39901402],
#        [50.39901402],
#        [50.43796002],
#        [50.43796002],
#        [50.44769652],
#        [50.44769652],
#        [50.45743301],
#        [50.45743301],
#        [50.45743301],
#        [50.45743301],
#        [50.45743301],
#        [50.45743301],
#        [50.46716951],
#        [50.46716951],
#        [50.46716951],
#        [50.46716951],
#        [50.515852  ],
#        [50.515852  ],
#        [50.554798  ],
#        [50.554798  ],
#        [50.5645345 ],
#        [50.5645345 ],
#        [50.57427099],
#        [50.57427099],
#        [50.59374399],
#        [50.59374399],
#        [50.61321699],
#        [50.61321699],
#        [50.61321699],
#        [50.61321699],
#        [50.71058197],
#        [50.71058197],
#        [50.77873746],
#        [50.77873746],
#        [50.83715645],
#        [50.83715645],
#        [50.94425793],
#        [50.94425793]])
